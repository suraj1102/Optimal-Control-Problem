# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

plt.style.use('tableau-colorblind10')
sns.set_palette("colorblind")

# %%
OUTPUT_DIR = "outputs"
PLOT_DIR = os.path.join(OUTPUT_DIR, "plots")
MODEL_DIR = os.path.join(OUTPUT_DIR, "models")
RESULTS_DIR = os.path.join(OUTPUT_DIR, "results")

SEARCH_KEY = "survival_3"

# %%
results_dict = {}
run_names = [f.removesuffix(".pkl") for f in os.listdir(RESULTS_DIR) if SEARCH_KEY in f.lower() and f.endswith('.pkl')]

for run_name in run_names:
    result_path = os.path.join(RESULTS_DIR, f"{run_name}.pkl")
    with open(result_path, "rb") as f:
        result = pickle.load(f)
        results_dict[run_name] = result

# %%
plt.figure(figsize=(8, 5))
for run_name, result in results_dict.items():
    timesteps = result["timesteps"]
    mean_rewards = result["mean_rewards"]
    plt.plot(timesteps, mean_rewards, marker=".", label=run_name)

plt.xlabel("Timesteps")
plt.ylabel("Mean Reward")
plt.title("Mean Reward vs Timesteps")
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %%
# Plot cumulative reward for each run
plt.figure(figsize=(8, 5))
for run_name, result in results_dict.items():
    timesteps = result["timesteps"]
    mean_rewards = result["mean_rewards"]
    cumulative_rewards = np.cumsum(mean_rewards)
    plt.plot(timesteps, cumulative_rewards, marker=".", label=run_name)

plt.xlabel("Timesteps")
plt.ylabel("Cumulative Reward")
plt.title("Cumulative Reward vs Timesteps")
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()
